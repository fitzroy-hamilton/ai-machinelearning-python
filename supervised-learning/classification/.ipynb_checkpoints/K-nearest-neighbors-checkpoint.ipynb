# %% [markdown]
# # K nearest neighbors (kNN)
#
# K nearest neighbors (kNN) is one of the simplest learning strategies: given a new, unknown observation, look up in your reference database which ones have the closest features and assign the predominant class.

# %% [markdown]
# ## Importer les dépendances

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use('seaborn')

# %% [markdown]
# ## Importer le dataset

# %%
from sklearn import datasets
iris = datasets.load_iris()
X, y = iris.data, iris.target

# %% [markdown]
# ## Construction du modèle (kNN)

# %%
from sklearn import neighbors
knn = neighbors.KNeighborsClassifier(n_neighbors=5)
knn.fit(X, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %% [markdown]
# ## Faire de nouvelles prédictions (kNN)

# %%
# What kind of iris has 3cm x 5cm sepal and 4cm x 2cm petal?
# call the "predict" method:
result = knn.predict([[3, 5, 4, 2],])
print(iris.target_names[result])
# Out:
# ['versicolor']

# %% [markdown]
# On peut également faire des prédictions probabilistiques :

# %%
knn.predict_proba([[3, 5, 4, 2],])
# Out:
# array([[ 0. ,  0.8,  0.2]])

# %% [markdown]
# ## Visualiser les résultats (kNN)

# %%
from fig_code import plot_iris_knn
plot_iris_knn()

# %% [markdown]
# ## Construction du modèle (SVC)

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state = 0)
classifier.fit(X, y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=0, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# ## Faire de nouvelles prédictions (SVC)

# %%
result = classifier.predict([[3, 5, 4, 2],])
print(iris.target_names[result])
# Out:
# ['versicolor']

# %% [markdown]
# ## Visualiser les résultats (SVC) **TODO**

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = X, y
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
#X3, X4 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
#                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
#plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel(), X3.ravel(), X4.ravel()]).T).reshape(X1.shape),
#             alpha = 0.4, cmap = ListedColormap(('red', 'green', 'blue')))
plt.xlim(X1.min() + 0.85, X1.max() - 0.85)
plt.ylim(X2.min() + 0.85, X2.max() - 0.85)
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green', 'blue'))(i), label = j)
#plt.title('Résultats')
plt.xlabel('sepal length (cm)')
plt.ylabel('sepal width (cm)')
#plt.legend()
plt.show()
